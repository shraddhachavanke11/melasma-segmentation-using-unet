# %%
import os 
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.layers import Input

os.environ["PYTHONHASHSEED"] = str(42)
np.random.seed(42)
tf.random.set_seed(42)

batch_size = 4
lr = 1e-4
epochs = 1
height = 256
width = 256

dataset_path = os.path.join("D:/cv/newCvcp/dataset", "D:/cv/newCvcp/dataset/nonaug")
files_dir = os.path.join("D:/cv/newCvcp/files", "D:/cv/newCvcp/files/non_aug")

model_file = os.path.join(files_dir, "unet-non-aug.keras")
log_file = os.path.join(files_dir, "log-test.csv")

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

create_dir(files_dir)
create_dir(dataset_path)

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)
    
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    
    b1 = conv_block(p4, 1024)
    
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = Model(inputs, outputs, name="UNET")
    return model

def load_data(path):
    train_x = sorted(glob(os.path.join(path, "train", "images", "*")))
    train_y = sorted(glob(os.path.join(path, "train", "masks", "*")))
    
    valid_x = sorted(glob(os.path.join(path, "valid", "images", "*")))
    valid_y = sorted(glob(os.path.join(path, "valid", "masks", "*")))
    return (train_x, train_y), (valid_x, valid_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = x / 255.0
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = x / 255.0
    x = np.expand_dims(x, axis=-1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
    x.set_shape([height, width, 3])
    y.set_shape([height, width, 1])
    return x, y

def tf_dataset(x, y, batch=8):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

(train_x, train_y), (valid_x, valid_y) = load_data(dataset_path)
print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

model = build_unet((height, width, 3))
model.summary()

opt = tf.keras.optimizers.Adam(lr)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["acc"])

callbacks = [
    ModelCheckpoint(model_file, verbose=1, save_best_only=False),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    CSVLogger(log_file),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
]
# Out:
# Train: 185 - 185
# Valid: 22 - 22
# Model: "UNET"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │  2,097,664 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    590,080 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         65 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,055,297 (118.47 MB)
#  Trainable params: 31,043,521 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
model.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.4559 - loss: 0.8270
# Epoch 1: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 382s 8s/step - acc: 0.4579 - loss: 0.8244 - val_acc: 0.2263 - val_loss: 0.8023 - learning_rate: 1.0000e-04
# Epoch 2/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.7595 - loss: 0.4876
# Epoch 2: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 350s 7s/step - acc: 0.7598 - loss: 0.4871 - val_acc: 0.2240 - val_loss: 1.2194 - learning_rate: 1.0000e-04
# Epoch 3/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.7967 - loss: 0.4130
# Epoch 3: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 352s 7s/step - acc: 0.7970 - loss: 0.4127 - val_acc: 0.2268 - val_loss: 2.2512 - learning_rate: 1.0000e-04
# Epoch 4/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.8058 - loss: 0.3984
# Epoch 4: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 353s 8s/step - acc: 0.8060 - loss: 0.3982 - val_acc: 0.3498 - val_loss: 1.3045 - learning_rate: 1.0000e-04
# Epoch 5/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - acc: 0.8152 - loss: 0.3750
# Epoch 5: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 379s 8s/step - acc: 0.8153 - loss: 0.3748 - val_acc: 0.3331 - val_loss: 1.6800 - learning_rate: 1.0000e-04
# Epoch 6/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - acc: 0.8305 - loss: 0.3510
# Epoch 6: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 370s 8s/step - acc: 0.8306 - loss: 0.3507 - val_acc: 0.4134 - val_loss: 1.1903 - learning_rate: 1.0000e-05
# Epoch 7/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - acc: 0.8479 - loss: 0.3212
# Epoch 7: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 368s 8s/step - acc: 0.8479 - loss: 0.3212 - val_acc: 0.5965 - val_loss: 0.6508 - learning_rate: 1.0000e-05
# Epoch 8/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.8515 - loss: 0.3126
# Epoch 8: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 354s 8s/step - acc: 0.8515 - loss: 0.3125 - val_acc: 0.7037 - val_loss: 0.5408 - learning_rate: 1.0000e-05
# Epoch 9/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - acc: 0.8549 - loss: 0.3063
# Epoch 9: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 372s 8s/step - acc: 0.8550 - loss: 0.3063 - val_acc: 0.7454 - val_loss: 0.4834 - learning_rate: 1.0000e-05
# Epoch 10/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - acc: 0.8586 - loss: 0.3003
# Epoch 10: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 386s 8s/step - acc: 0.8586 - loss: 0.3002 - val_acc: 0.7716 - val_loss: 0.4335 - learning_rate: 1.0000e-05
# Epoch 11/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.8625 - loss: 0.2942
# Epoch 11: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 359s 8s/step - acc: 0.8625 - loss: 0.2941 - val_acc: 0.7926 - val_loss: 0.3934 - learning_rate: 1.0000e-05
# Epoch 12/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.8661 - loss: 0.2880
# Epoch 12: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 362s 8s/step - acc: 0.8661 - loss: 0.2879 - val_acc: 0.8061 - val_loss: 0.3674 - learning_rate: 1.0000e-05
# Epoch 13/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - acc: 0.8695 - loss: 0.2817
# Epoch 13: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 430s 9s/step - acc: 0.8695 - loss: 0.2816 - val_acc: 0.8130 - val_loss: 0.3552 - learning_rate: 1.0000e-05
# Epoch 14/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - acc: 0.8733 - loss: 0.2751
# Epoch 14: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 375s 8s/step - acc: 0.8733 - loss: 0.2750 - val_acc: 0.8166 - val_loss: 0.3510 - learning_rate: 1.0000e-05
# Epoch 15/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - acc: 0.8776 - loss: 0.2673
# Epoch 15: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 388s 8s/step - acc: 0.8776 - loss: 0.2673 - val_acc: 0.8150 - val_loss: 0.3543 - learning_rate: 1.0000e-05
# Epoch 16/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - acc: 0.8815 - loss: 0.2597
# Epoch 16: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 369s 8s/step - acc: 0.8815 - loss: 0.2597 - val_acc: 0.8132 - val_loss: 0.3608 - learning_rate: 1.0000e-05
# Epoch 17/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - acc: 0.8856 - loss: 0.2522
# Epoch 17: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 369s 8s/step - acc: 0.8856 - loss: 0.2522 - val_acc: 0.8159 - val_loss: 0.3589 - learning_rate: 1.0000e-05
# Epoch 18/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.8911 - loss: 0.2431
# Epoch 18: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 364s 8s/step - acc: 0.8910 - loss: 0.2431 - val_acc: 0.8124 - val_loss: 0.3774 - learning_rate: 1.0000e-05
# Epoch 19/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.8954 - loss: 0.2360
# Epoch 19: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 364s 8s/step - acc: 0.8954 - loss: 0.2359 - val_acc: 0.8404 - val_loss: 0.3228 - learning_rate: 1.0000e-06
# Epoch 20/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9001 - loss: 0.2264
# Epoch 20: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 357s 8s/step - acc: 0.9000 - loss: 0.2264 - val_acc: 0.8425 - val_loss: 0.3199 - learning_rate: 1.0000e-06
# Epoch 21/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9016 - loss: 0.2237
# Epoch 21: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 355s 8s/step - acc: 0.9016 - loss: 0.2237 - val_acc: 0.8424 - val_loss: 0.3191 - learning_rate: 1.0000e-06
# Epoch 22/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9027 - loss: 0.2216
# Epoch 22: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 360s 8s/step - acc: 0.9026 - loss: 0.2216 - val_acc: 0.8424 - val_loss: 0.3186 - learning_rate: 1.0000e-06
# Epoch 23/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9036 - loss: 0.2197
# Epoch 23: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 354s 7s/step - acc: 0.9036 - loss: 0.2197 - val_acc: 0.8425 - val_loss: 0.3183 - learning_rate: 1.0000e-06
# Epoch 24/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9045 - loss: 0.2179
# Epoch 24: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 355s 8s/step - acc: 0.9045 - loss: 0.2179 - val_acc: 0.8429 - val_loss: 0.3180 - learning_rate: 1.0000e-06
# Epoch 25/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9053 - loss: 0.2163
# Epoch 25: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 356s 8s/step - acc: 0.9053 - loss: 0.2163 - val_acc: 0.8433 - val_loss: 0.3178 - learning_rate: 1.0000e-06
# Epoch 26/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9061 - loss: 0.2147
# Epoch 26: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 354s 8s/step - acc: 0.9061 - loss: 0.2147 - val_acc: 0.8438 - val_loss: 0.3178 - learning_rate: 1.0000e-06
# Epoch 27/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9069 - loss: 0.2131
# Epoch 27: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 351s 7s/step - acc: 0.9068 - loss: 0.2132 - val_acc: 0.8443 - val_loss: 0.3178 - learning_rate: 1.0000e-06
# Epoch 28/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9076 - loss: 0.2117
# Epoch 28: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 352s 7s/step - acc: 0.9076 - loss: 0.2117 - val_acc: 0.8448 - val_loss: 0.3180 - learning_rate: 1.0000e-06
# Epoch 29/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9083 - loss: 0.2102
# Epoch 29: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 352s 7s/step - acc: 0.9083 - loss: 0.2102 - val_acc: 0.8452 - val_loss: 0.3183 - learning_rate: 1.0000e-06
# Epoch 30/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9093 - loss: 0.2083
# Epoch 30: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 348s 7s/step - acc: 0.9093 - loss: 0.2083 - val_acc: 0.8453 - val_loss: 0.3180 - learning_rate: 1.0000e-07
# Epoch 31/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9094 - loss: 0.2081
# Epoch 31: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 354s 8s/step - acc: 0.9094 - loss: 0.2081 - val_acc: 0.8454 - val_loss: 0.3180 - learning_rate: 1.0000e-07
# Epoch 32/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9095 - loss: 0.2079
# Epoch 32: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 349s 7s/step - acc: 0.9095 - loss: 0.2079 - val_acc: 0.8454 - val_loss: 0.3180 - learning_rate: 1.0000e-07
# Epoch 33/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9096 - loss: 0.2077
# Epoch 33: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 347s 7s/step - acc: 0.9096 - loss: 0.2078 - val_acc: 0.8454 - val_loss: 0.3181 - learning_rate: 1.0000e-07
# Epoch 34/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 34: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 350s 7s/step - acc: 0.9097 - loss: 0.2076 - val_acc: 0.8455 - val_loss: 0.3181 - learning_rate: 1.0000e-08
# Epoch 35/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 35: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 351s 7s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-08
# Epoch 36/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 36: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 352s 7s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-08
# Epoch 37/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 37: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 356s 8s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-08
# Epoch 38/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 38: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 355s 8s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-09
# Epoch 39/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 39: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 359s 8s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-09
# Epoch 40/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 40: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 354s 8s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-09
# Epoch 41/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 41: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 353s 7s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-09
# Epoch 42/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 42: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 353s 8s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-10
# Epoch 43/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 43: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 354s 8s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-10
# Epoch 44/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 44: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 355s 8s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-10
# Epoch 45/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 45: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 352s 7s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-10
# Epoch 46/500
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - acc: 0.9097 - loss: 0.2075
# Epoch 46: saving model to D:/cv/newCvcp/file/non_aug\unet-non-aug.keras
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 358s 8s/step - acc: 0.9097 - loss: 0.2075 - val_acc: 0.8455 - val_loss: 0.3180 - learning_rate: 1.0000e-11
